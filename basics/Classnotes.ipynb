# %%
a=3

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
b=3.14

# %%
print(type(b))
# Out:
# <class 'float'>

# %%
c= "Swathi"

# %%
print(type(c))
# Out:
# <class 'str'>

# %%
d=b

# %%
print(type(d))
# Out:
# <class 'float'>

# %%
d= int(b)

# %%
print(d)
# Out:
# 3

# %%
e= str(d)

# %%
e
# Out:
# '3'

# %%
a= 7
b= 7.0
c = a * b

# %%
print(type(c))
# Out:
# <class 'float'>

# %%
print(c)
# Out:
# 49.0

# %%
c = 3
d= float(c)

# %%
print(3+8)
# Out:
# 11

# %%
print("Hello")
# Out:
# Hello

# %%
print(type(d))
# Out:
# <class 'float'>

# %%
print('Swathi')
print('Sakinala')
# Out:
# Swathi
# Sakinala

# %%
a= 3
b= 4
c= a+b
print(c)
# Out:
# 3 4

# %%
print(a,b, sep = '--')
# Out:
# 3--4

# %%
print(a,b, sep = "\t")
# Out:
# 3	4

# %%
print("Swathi", "Sakinala",sep = "\t")
# Out:
# Swathi	Sakinala

# %% [markdown]
# '\n' is for the new line and '\t' is for the tab space

# %%
a= 3
b= 4
c= a+b
print(c)
# Out:
# 7

# %%
a= input()
# Out:
# 12

# %%
a
# Out:
# '12'

# %%
num1 = input('Please Enter Your Number')
# Out:
# Please Enter Your Number2

# %%
num1
# Out:
# '2'

# %%
num2 = input('Please enter second number')
# Out:
# Please enter second number5

# %%
num2
# Out:
# '5'

# %%
result = num1 + num2

# %%
result
# Out:
# '25'

# %%
type(num1)
# Out:
# str

# %%
num1 = int(num1)

# %%
num1
# Out:
# 2

# %%
num2 = int(num2)
num2
# Out:
# 5

# %%
result = num1 - num2
result
# Out:
# -3

# %% [markdown]
# Conditional statements/Condition

# %%
if (X Happens), Ill go X related task , else I wont

# %%
if- else, elif

# %%
a=3
a
# Out:
# 3

# %%
a==5
# Out:
# False

# %%
if(condition):
  "Execute this"
else:
  "Execute this one"

# %%
if(a>3):
  print("Matching")
  print("Yes you are right")
  print("Perfect")
else:
  print("Not Matching")
# Out:
# Not Matching
