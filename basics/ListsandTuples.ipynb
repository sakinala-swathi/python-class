# %%
a= "Swathi"

# %%
a[1]
# Out:
# 'w'

# %%
a[1] = "S"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2426956835.py in <cell line: 0>()
# ----> 1 a[1] = "S"
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# len() function is used to find the length of the variable.

# %%
a = "Swathi"

# %%
print(len(a))
# Out:
# 6

# %%
0 to len-1
0 to 5
0 --- S
1 ---- W
2 -----a
3 -----t
4 -----h
5 ------i

# %% [markdown]
# Concatenate - Adding two or more strings together using + operator

# %%
 n = "Swathi"
 m = "Sakinala"

# %%
p = n + m

# %%
p
# Out:
# 'SwathiSakinala'

# %%
q = n+ " " + m
q
# Out:
# 'Swathi Sakinala'

# %%
 r = n + \t + m
 r
# Out:
#   File "/tmp/ipython-input-4004454816.py", line 1
#     r = n + \t + m
#              ^
# SyntaxError: unexpected character after line continuation character

# %%
\t---- tab spacing     \n--new line     \v--vertical spacing.   \r-- regular expression

# %%
in not in

# %%
n = "Swathi"
'a' in n
# Out:
# True

# %%
n = "Swathi"
'a' not in n
# Out:
# False

# %%
r -- raw printing

# %%
print(r'\n')
# Out:
# \n

# %% [markdown]
# Upper case and lower case---- upper() and lower()

# %%
c= "I am a Good Girl"
print(c.upper())
print(c.lower())
# Out:
# I AM A GOOD GIRL
# i am a good girl

# %% [markdown]
# split()--- Splits the variable/ strings upon the given condition

# %%
words = "a b c d"
words.split()
# Out:
# ['a', 'b', 'c', 'd']

# %% [markdown]
# . format() --- Formatting

# %%
name = input ("Enter your name")
print("hi {}, How are you?".format(name))
# Out:
# Enter your nameSwathi
# hi Swathi, How are you?

# %%
marks = 20
marks1 = 30
marks 2

# %% [markdown]
# List -- A list is used to store multiple values in a single variable.
#  List--- []

# %%
marks = [80,90,100,75,20]
#this is the list of integers

# %%
marks
# Out:
# [80, 90, 100, 75, 20]

# %%
names = ["John", "swathi", "xyz"]
names
# Out:
# ['John', 'swathi', 'xyz']

# %%
names[2]
# Out:
# 'xyz'

# %%
data = [10, "Python", 3.5 , True]
data
# Out:
# [10, 'Python', 3.5, True]

# %% [markdown]
# Indexing on list..
# - Indexing always starts with Zero
# - Ends with len-1

# %%
data[-5]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-1454318739.py in <cell line: 0>()
# ----> 1 data[-5]
#
# IndexError: list index out of range

# %%
names[-1]
# Out:
# 'xyz'

# %% [markdown]
# Lists are MUTABLE.
# we can change the value after creation.

# %%
languages = ["Java", "Python", "C++"]
languages[0]
# Out:
# 'Java'

# %%
languages[0] = "Javascript"
languages
# Out:
# ['Javascript', 'Python', 'C++']

# %% [markdown]
# Adding elements in the list.--- append

# %%
languages.append("Bye")
languages
# Out:
# ['Javascript',
#  'Python',
#  'C++',
#  'Bye',
#  'Bye',
#  'Bye',
#  'Bye',
#  'Bye',
#  'Bye',
#  'Bye',
#  'Bye',
#  'Bye',
#  'Bye']

# %% [markdown]
# Insert -- provide specific position

# %%
languages.insert(1, "Ruby")

# %%
languages
# Out:
# ['Javascript',
#  'Ruby',
#  'Python',
#  'C++',
#  'Bye',
#  'Bye',
#  'Bye',
#  'Bye',
#  'Bye',
#  'Bye',
#  'Bye',
#  'Bye',
#  'Bye',
#  'Bye']

# %% [markdown]
# Remove -- used to remove the lements in the list

# %%
languages.remove("C++")

# %%
languages
# Out:
# ['Javascript',
#  'Ruby',
#  'Python',
#  'Bye',
#  'Bye',
#  'Bye',
#  'Bye',
#  'Bye',
#  'Bye',
#  'Bye',
#  'Bye',
#  'Bye',
#  'Bye']

# %%
languages.remove("Bye")

# %%
languages
# Out:
# ['Javascript', 'Ruby', 'Python', 'Bye']

# %% [markdown]
# pop() -- Removes the last element

# %%
languages.pop()
# Out:
# 'Bye'

# %%
languages
# Out:
# ['Javascript', 'Ruby', 'Python']

# %% [markdown]
# len() -- tells how many elements are present in the list

# %%
print(len(languages))
# Out:
# 3

# %%
languages
# Out:
# ['Javascript', 'Ruby', 'Python']

# %%
languages ---- 3
for 1st iteration, it will assign lang = "Javascript"
for 2nd iteration, it will assign lang = "Ruby"
for 3rd iteration, it will assign lang = "Python"

# %%
for lang in languages:
  print(lang)
# Out:
# Javascript
# Ruby
# Python

# %%
lang
# Out:
# 'Python'

# %%
data
# Out:
# [10, 'Python', 3.5, True]

# %%
for lang in data:
  print(lang)
# Out:
# 10
# Python
# 3.5
# True

# %%
ints = [10, 20, 30, 40, 50]
for i in ints:
  print(i+1)
# Out:
# 11
# 21
# 31
# 41
# 51

# %% [markdown]
# TUPLES: similar to lists. Difference - ()
# Mutability.

# %%
days = ("Monday", "Tuesday", "Wednesday")

# %%
days[0]
# Out:
# 'Monday'

# %%
days[0]= "Sunday"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3444482214.py in <cell line: 0>()
# ----> 1 days[0]= "Sunday"
#
# TypeError: 'tuple' object does not support item assignment
